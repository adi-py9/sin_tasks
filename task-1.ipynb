# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('/home/adityak/Desktop/Basic_LinkedInDataExport_02-03-2023./Connections.csv')

# %%
df
# Out:
#     First Name   Last Name                Email Address            Company  \
# 0       Maxime      Jublou                          NaN            naas.ai
# 1      Tanisha           G                          NaN               FRND
# 2       Nimish     Kashyap                          NaN       NexSeed Club
# 3        Karin  Hedenstrom                          NaN           Polarium
# 4       RISHIT       ANAND                          NaN             JUSPAY
# ..         ...         ...                          ...                ...
# 163   Rakshith   Vikramraj                          NaN            Kaiburr
# 164      Pooja   Dinakaran                          NaN             Amazon
# 165     Ankita       Gupta          anki98933@gmail.com       Silicon Labs
# 166     Fabian     Sanjose  fabiansanjose2698@gmail.com           Deloitte
# 167      Kruti       Patel                          NaN  Intel Corporation
#
#                                   Position  \
# ...

# %%
#df=df.drop('Connected On')

# %%
df.reindex()
# Out:
#     First Name   Last Name                Email Address            Company  \
# 0       Maxime      Jublou                          NaN            naas.ai
# 1      Tanisha           G                          NaN               FRND
# 2       Nimish     Kashyap                          NaN       NexSeed Club
# 3        Karin  Hedenstrom                          NaN           Polarium
# 4       RISHIT       ANAND                          NaN             JUSPAY
# ..         ...         ...                          ...                ...
# 163   Rakshith   Vikramraj                          NaN            Kaiburr
# 164      Pooja   Dinakaran                          NaN             Amazon
# 165     Ankita       Gupta          anki98933@gmail.com       Silicon Labs
# 166     Fabian     Sanjose  fabiansanjose2698@gmail.com           Deloitte
# 167      Kruti       Patel                          NaN  Intel Corporation
#
#                                   Position  \
# ...

# %%
#df =df.get('Position', default="DAta")

# %%
#df.loc['2']

# %%
#df = df.drop(df.columns[[3],[5],[6]], axis=1)

# %%
df=df.drop(['Email Address','Position'],axis=1)

# %%
df['Name']=df['First Name']+' '+df['Last Name']

# %%
df=df.drop(['First Name','Last Name'],axis=1)

# %%
gf = df.groupby('Company')

# %%
gf.last()
# Out:
#                                                Connected On                                                                                                                                                                                                                                          \
# Company
# AIESEC in India                                 13 Mar 2021                                   ...
# AMD                                             26 Aug 2022                                   ...
# Absa Bank Kenya                                 23 Jun 2022                                   ...
# Accenture                                       03 Feb 2022                                   ...
# Accenture in India                              19 Sep 2020                                   ...
# ...                                                                                           ...
# ...

# %%
gf

# %%
company=[]
member=[]
weight=[]

# %%
count1=0;
count2=150
for name,group in gf:
    for i in range(len(group)):
        company.append(count1)
        member.append(count2)
        weight.append(1)
        count2=count2+1
    count1=count1+1

# %%
company
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  5,
#  5,
#  6,
#  6,
#  6,
#  6,
#  6,
#  7,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  13,
#  14,
#  15,
#  16,
#  17,
#  18,
#  18,
#  18,
#  19,
#  20,
#  21,
#  22,
#  22,
#  23,
#  24,
#  25,
#  26,
#  27,
#  28,
#  29,
#  29,
#  29,
#  29,
#  29,
#  30,
#  31,
#  32,
#  33,
#  34,
#  35,
#  35,
#  35,
#  35,
#  36,
#  37,
#  38,
#  39,
#  40,
#  41,
#  41,
#  41,
#  42,
#  43,
#  44,
#  44,
#  45,
#  46,
#  47,
#  48,
#  49,
#  49,
#  49,
#  50,
#  51,
#  52,
#  53,
#  54,
#  55,
#  56,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  57,
#  58,
#  59,
#  59,
#  60,
#  61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  67,
#  67,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  74,
#  75,
#  76,
#  77,
#  78,
#  78,
#  78,
#  79,
#  80,
#  81,
#  82,
#  82,
#  82,
#  83,
#  84,
#  85,
#  86,
#  86,
#  87,
#  88,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  97,
#  98,
#  99,
#  100,
#  100,
# ...

# %%
company_grouping=pd.DataFrame(list(zip(company,member,weight)))

# %%
company_grouping
# Out:
#        0    1  2
# 0      0  150  1
# 1      1  151  1
# 2      2  152  1
# 3      3  153  1
# 4      4  154  1
# ..   ...  ... ..
# 149  106  299  1
# 150  107  300  1
# 151  108  301  1
# 152  109  302  1
# 153  109  303  1
#
# [154 rows x 3 columns]

# %%
company_grouping.to_csv(r'/home/adityak/anaconda3/bin/sin_tasks/company.txt',sep=' ',index=False)

# %%
company_grouping
# Out:
#        0    1  2
# 0      0  150  1
# 1      1  151  1
# 2      2  152  1
# 3      3  153  1
# 4      4  154  1
# ..   ...  ... ..
# 149  106  299  1
# 150  107  300  1
# 151  108  301  1
# 152  109  302  1
# 153  109  303  1
#
# [154 rows x 3 columns]
